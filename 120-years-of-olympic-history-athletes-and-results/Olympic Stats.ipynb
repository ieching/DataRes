# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("athlete_events.csv")

# %%
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
# ID        271116 non-null int64
# Name      271116 non-null object
# Sex       271116 non-null object
# Age       261642 non-null float64
# Height    210945 non-null float64
# Weight    208241 non-null float64
# Team      271116 non-null object
# NOC       271116 non-null object
# Games     271116 non-null object
# Year      271116 non-null int64
# Season    271116 non-null object
# City      271116 non-null object
# Sport     271116 non-null object
# Event     271116 non-null object
# Medal     39783 non-null object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
def convert_medal(medal):
    if medal == "Gold":
        return 1
    elif medal == "Silver":
        return 2
    elif medal == "Bronze":
        return 3
    elif np.isnan(medal):
        return 0

# %%
df["Medal"] = df["Medal"].apply(convert_medal)

# %%
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event  Medal
# 0       Basketball Men's Basketball      0
# 1      Judo Men's Extra-Lightweight      0
# ...

# %%
df[df["Sport"] == "Basketball"]
# Out:
#             ID                                     Name Sex   Age  Height  \
# 0            1                                A Dijiang   M  24.0   180.0
# 167         69                        Tamara Abalde Daz   F  19.0   185.0
# 250        124                    Youssef Mohamed Abbas   M  31.0     NaN
# 264        136                         Alessandro Abbio   M  29.0   195.0
# 346        192       Ahmed El-Sayed Abdel Hamid Mobarak   M  25.0   189.0
# 359        199                        Amir Abdel Meguid   M  23.0   178.0
# 360        199                        Amir Abdel Meguid   M  27.0   178.0
# 363        202                     Awad Abdel Nabi Awad   M  19.0   198.0
# 364        202                     Awad Abdel Nabi Awad   M  23.0   198.0
# 490        270                       Alaa El-Din Abdoun   M  23.0   188.0
# 609        351               Julius Shareef Abdur-Rahim   M  23.0   202.0
# 641        370                             Shigeaki Abe   M  24.0   178.0
# ...

# %%
numeric_df = pd.DataFrame([df[df["Sport"] == "Basketball"]["Age"], df[df["Sport"] == "Basketball"]["Height"], df[df["Sport"] == "Basketball"]["Weight"], df[df["Sport"] == "Basketball"]["Year"], df[df["Sport"] == "Basketball"]["Medal"]]).transpose()

# %%
numeric_df.head()
# Out:
#       Age  Height  Weight    Year  Medal
# 0    24.0   180.0    80.0  1992.0    0.0
# 167  19.0   185.0    72.0  2008.0    0.0
# 250  31.0     NaN     NaN  1952.0    0.0
# 264  29.0   195.0    85.0  2000.0    0.0
# 346  25.0   189.0    85.0  1972.0    0.0

# %%
sns.pairplot(numeric_df)
# Out:
# c:\users\iechi\appdata\local\programs\python\python36\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# c:\users\iechi\appdata\local\programs\python\python36\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
teams = df["Team"].unique()
medals = []

for team in teams:
    total = df[df["Team"] == team]["Medal"].sum()
    medals.append(total)

# %%
team_df = pd.DataFrame([teams, medals]).transpose()
team_df.columns = ['Team', 'Total Medals']

# %%
team_df.head()
# Out:
#              Team Total Medals
# 0           China         1762
# 1         Denmark         1100
# 2  Denmark/Sweden            6
# 3     Netherlands         2089
# 4   United States         9197

# %%
team_df = team_df.sort_values(by="Total Medals", ascending=False)

# %%
team_df.head(10)
# Out:
#              Team Total Medals
# 4   United States         9197
# 29   Soviet Union         4521
# 42        Germany         3967
# 94  Great Britain         3399
# 9          France         3222
# 16          Italy         3003
# 85         Sweden         2924
# 46      Australia         2781
# 44         Canada         2472
# 20         Russia         2247

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
# ID        271116 non-null int64
# Name      271116 non-null object
# Sex       271116 non-null object
# Age       261642 non-null float64
# Height    210945 non-null float64
# Weight    208241 non-null float64
# Team      271116 non-null object
# NOC       271116 non-null object
# Games     271116 non-null object
# Year      271116 non-null int64
# Season    271116 non-null object
# City      271116 non-null object
# Sport     271116 non-null object
# Event     271116 non-null object
# Medal     271116 non-null int64
# dtypes: float64(3), int64(3), object(9)
# memory usage: 31.0+ MB

# %%
len(df['Name'].unique())
# Out:
# 134732

# %%
Name = []
Sex = []
Age = []
Height = []
Weight = []
Team = [] 
Year = []
Sport = []
Event = []
Medal = []
